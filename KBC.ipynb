# %%
print("LETS PLAY KBC\n")
print("HERE IS YOUR FRIST QUESTION\n")
print("WHO IS THE MLA OF UDAIPUR\n")

x=input("ENTER YOUR ANSWER :\n")
amount=0
if x== "ANAS KHAN":
    print("WOW YOUR ANSWER IS RIGHT\n")
    print("YOU WIN 1000RS\n")
    amount=1000
    print("YOUR SECOND QUESTION IS\n")
    print("LARGEST OCEAN IN THE WORLD\n")
    b=input("enter your answer:\n")
    if b=="PACEFIC":
        print("your answer is right\n")
        print("you win 2000rs")
        amount=2000
        print("YOUR THIRD QUESTION IS\n")
        print("who win 2005 world cup\n")
        a=input("enter your answer:\n")
        if a=="INDIA":
            print("your answer is right\n")
            print("you win 3000rs")
            amount=3000
        else:
            print("your anaser id wrong")
            print("you lost\n")
            print("your winning amount is:",amount)
    else:
        print("your anaser is wrong")
        print("you lost\n")
        print("your winning amount is:",amount)
        
    
    
else:
    print("YOUR ANSWER IS WRONG \n")
    print("CORRECT ANSWER IS ANAS KHAN")
    print("you lost\n","YOUR WINNING AMOUNT:",amount)
# Out:
# LETS PLAY KBC
#
# HERE IS YOUR FRIST QUESTION
#
# WHO IS THE MLA OF UDAIPUR
#
# ENTER YOUR ANSWER :
# ANAS KHAN
# WOW YOUR ANSWER IS RIGHT
#
# YOU WIN 1000RS
#
# YOUR SECOND QUESTION IS
#
# LARGEST OCEAN IN THE WORLD
#
# enter your answer:
# INDAIN OCEAN
# your anaser is wrong
# you lost
#
# your winning amount is: 1000

# %%
questions=[["WHAT IS CAPITAL OF INDIA","RAJUSTHAN","JAIPUR","UDAIPUR","DELHI"],["WHO IS THE PRIME MINISTER OF INDAI","PM NARENDER MODI","ALEXA BETH","APJ ABDUL KALAM","RAHUL GANDHI"],["WHO KNOWN AS THE ROCKET MAN OF INDAI","BHAGAT SINGH","BR AMBETHKAR","APJ ABDUL KALAM","NONE OF THIS"],["WHO WON 2005 WORLD CUP","INDAI",'AUSTRALIA',"SOUTH AFRICA","NONE OF THESE"],["WHICK CITY IS KNWON AS TH PINK CITY OF INDIA","JAIPUR","AJMER","KOTA","UDAIPUR"],["WHO WROTE INDAI'S NATIONAL ANTHEM.","ANAS KHAN","RAFEH GERIB","RABINDRANATH TAGORE","DANISH BHAI"]]
AMOUNT=[5000,10000,20000,50000,100000,500000]
TAKEMONEY=0
print("-----WELCOME TO KBC-----")
for i in range(0,len(questions)):
    if i==0:
        print("HERE IS YOUR FRIST QUESTION FOR 5000RS\n","Q.1",questions[0][0])
        print(f"A.{questions[0][1]}          B.{questions[0][2]}")
        print(f"C.{questions[0][3]}          D.{questions[0][4]}","\n")
        print("CHIOSE YOUR ANSWER FROM(A-D)")
        take=input("ENTER YOUR CHOISE\n")
        if take=="D":
            print("YOUR ANSWER IS RIGHT\n","YOU WON 5000RS")
            print("NEXT QUESTION\n")
    
        else:
            print("YOU LOST!!!")
            print("TAKE HOME MONEY IS ",TAKEMONEY)
            break
    
    if i==1:
        print("HERE IS YOUR SECOND QUESTION FOR 10000RS\n","Q.2",questions[1][0])
        print(f"A.{questions[1][1]}          B.{questions[1][2]}")
        print(f"C.{questions[1][3]}          D.{questions[1][4]}","\n")
        print("CHIOSE YOUR ANSWER FROM(A-D)")
        take=input("ENTER YOUR CHOISE\n")
        if take=="A":
            print("YOUR ANSWER IS RIGHT\n","YOU WON 10000RS")
            print("NEXT QUESTION\n")
            
        else:
            print("YOU LOST!!!")
            print("TAKE HOME MONEY IS ",TAKEMONEY)
            break
    
    if i==2:
        print("HERE IS YOUR THIRD QUESTION FOR 20000RS\n","Q.3",questions[2][0])
        print(f"A.{questions[2][1]}          B.{questions[2][2]}")
        print(f"C.{questions[2][3]}          D.{questions[2][4]}","\n")
        print("CHIOSE YOUR ANSWER FROM(A-D)")
        take=input("ENTER YOUR CHOISE\n")
        if take=="C":
            print("YOUR ANSWER IS RIGHT\n","YOU WON 20000RS")
            print("NEXT QUESTION\n")
            TAKEMONEY=AMOUNT[2]
        else:
            print("YOU LOST!!!")
            print("TAKE HOME MONEY IS ",TAKEMONEY)
            break
    
    if i==3:
        print("HERE IS YOUR FORTH QUESTION FOR 50000RS\n","Q.4",questions[3][0])
        print(f"A.{questions[3][1]}          B.{questions[3][2]}")
        print(f"C.{questions[3][3]}          D.{questions[3][4]}","\n")
        print("CHIOSE YOUR ANSWER FROM(A-D)")
        take=input("ENTER YOUR CHOISE\n")
        if take=="B":
            print("YOUR ANSWER IS RIGHT\n","YOU WON 50000RS\n")
            print("NEXT QUESTION\n")
            TAKEMONEY=AMOUNT[2]
        else:
            print("YOU LOST!!!")
            print("TAKE HOME MONEY IS ",TAKEMONEY)
            break

    if i==4:
        print("HERE IS YOUR FIFTH QUESTION FOR 100000RS\n","Q.5",questions[4][0])
        print(f"A.{questions[4][1]}          B.{questions[4][2]}")
        print(f"C.{questions[4][3]}          D.{questions[4][4]}","\n")
        print("CHIOSE YOUR ANSWER FROM(A-D)")
        take=input("ENTER YOUR CHOISE\n")
        if take=="A":
            print("YOUR ANSWER IS RIGHT\n","YOU WON 100000RS\n")
            print("NEXT QUESTION")
            TAKEMONEY=AMOUNT[2]
           
        else:
            print("YOU LOST!!!")
            print("TAKE HOME MONEY IS ",TAKEMONEY)
            break
        
    if i==5:
        print("HERE IS YOUR FIFTH QUESTION FOR 500000RS\n","Q.6",questions[5][0])
        print(f"A.{questions[5][1]}          B.{questions[5][2]}")
        print(f"C.{questions[5][3]}          D.{questions[5][4]}","\n")
        print("CHIOSE YOUR ANSWER FROM(A-D)")
        take=input("ENTER YOUR CHOISE\n")
        if take=="C":
            print("YOUR ANSWER IS RIGHT\n","YOU WON 500000RS\n")

            TAKEMONEY=AMOUNT[5]
            print("YOU COMPLETE ALL THE QUESTIONS")
            print("YOUR WINNING AMOUNT IS\n",TAKEMONEY)
        else:
            print("YOU LOST!!!")
            print("TAKE HOME MONEY IS ",TAKEMONEY)
            break
# Out:
# -----WELCOME TO KBC-----
# HERE IS YOUR FRIST QUESTION FOR 5000RS
#  Q.1 WHAT IS CAPITAL OF INDIA
# A.RAJUSTHAN          B.JAIPUR
# C.UDAIPUR          D.DELHI
#
# CHIOSE YOUR ANSWER FROM(A-D)
# ENTER YOUR CHOISE
# D
# YOUR ANSWER IS RIGHT
#  YOU WON 5000RS
# NEXT QUESTION
#
# HERE IS YOUR SECOND QUESTION FOR 10000RS
#  Q.2 WHO IS THE PRIME MINISTER OF INDAI
# A.PM NARENDER MODI          B.ALEXA BETH
# C.APJ ABDUL KALAM          D.RAHUL GANDHI
#
# CHIOSE YOUR ANSWER FROM(A-D)
